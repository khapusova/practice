# %% [markdown]
# # **Курс "Програмування на мові Python"**
#
# ##### Викладачі:
# ##### Борисенко Павло Борисович
# ##### Щьоголєв Максим Олегович

# %% [markdown]
# ## **Практичне зайняття №9**
#
# ### Тема: "Лямбда-функції. Функції вищих порядків"

# %% [markdown]
# ### **Завдання 1 (1 бал)**
#
# Керівництво будівельної компанії вирішило підняти заробітні плати всім своїм працівникам на 30%. В залежності від спеціалізації та стажу працівники мають різну заробітну плату. Для підготовки звіту необхідно розрахувати нову заробітну плату для працівників компанії, а також суму індексації.
#
# Написати програму, яка буде генерувати таблицю для цього звіту. Початкова заробітна плата працівників подана у списку salary_list (у тисячах гривень).
#
# 1. Для підрахунку невідомих значень повинні використовуватись вбудовані функції вищих порядків.
#
# 2. Зарплата після індексації та сума індексації для працівників різних категорій повинні зберігатись у двох окремих списках. Порядок значень у кожному з нових списків повинен відповідати порядку значень у списку salary_list.
#
# 3. Кожне підраховане числове значення має бути округлене до сотих.
#
# 4. Дані повинні виводитись у вигляді:
#
# **Salary table:**
#
# **7.3 9.49 2.19**
#
# **8.5 11.05 2.55**
#
# **...**
#
# salary_list = [[7.3, 8.5, 11, 12.7, 15.2, 21.12, 27.35]]

# %%
products_list = [29.25, 48.99, 99.98, 124.65, 214.30, 543.90, 799.85]
skidki = []
cena = []
print('Discount table:', '\n')
cena = list(map(lambda x: round(x * 0.4, 2), products_list))
skidki = list(map(lambda x: round(x * 0.6, 2), products_list))
for i in range (len(products_list)):
    print (products_list[i],  '\t',  cena[i], ' ',  '\t',  skidki[i], '\n')
# Out:
# Discount table:
#
# 29.25 	 11.7   	 17.55
#
# 48.99 	 19.6   	 29.39
#
# 99.98 	 39.99   	 59.99
#
# 124.65 	 49.86   	 74.79
#
# 214.3 	 85.72   	 128.58
#
# 543.9 	 217.56   	 326.34
#
# 799.85 	 319.94   	 479.91

# %% [markdown]
# ### **Завдання 2 (2 бали)**
#
# Зазвичай рік має 365 днів. Однак у високосні роки додається ще один день - 29 лютого. Правила визначення високосного року такі:
#
# - Будь-який рік, що ділиться на 400 - високосний.
#
# - З тих років, що залишились, будь-який рік, що ділиться на 100 - **не** високосний.
#
# - З тих років, що залишились, будь-який рік, що ділиться на 4 - високосний.
#
# - Усі інші роки, що залишились - **не** високосні.
#
# 1) Створіть функцію, в якій за допомогою вбудованих функцій вищих порядків будуть визначатися високосні роки серед перелічених років у списку years. Створена функція має повертати список високосних років.
#
# 2) Створіть функцію вищих порядків, яка прийматиме на вхід попередню функцію та визначатиме кількість днів у місяці. Також функція повинна приймати на вхід ще 2 параметри: ціле число від 1 до 12 (місяць) та рік, як ціле чотирицифрове число. Ці значення корисувач має вводити з клавіатури. Перевірку введених даних слід виконувати поза межами функцій.

# %%
import numpy as np
def first(years):
    d1 = list(filter(lambda i: i % 400 == 0, years))
    d2 = list((filter(lambda i: i % 400 != 0, years)))
    d12 = list(filter(lambda i: i % 100 != 0 and i%4 == 0, d2))
    d22 =list(filter(lambda i: i % 100 == 0 or i%4 != 0, d2))
    for i in d12:
        d1.append(i)
    return d1
years = np.arange(1920, 2020 + 1, 1)
def main(func, mes, year):
    if mes == 2:
        if year in func:
            kilk = 29
        else:
            kilk = 28
    elif mes == 1 or mes == 3 or mes == 5 or mes == 7 or mes == 8 or mes == 10 or mes ==  12:
        kilk = 31
    else:
        kilk = 30
    return kilk
inp = input('Введіть номер місяця(від 1 до 12) й рік (від 1920 до 2020) через пробіл ').split()
mes = inp[0]
year = inp[1]
try:
    mes = int(mes)
    year = int(year)
    if not 0< mes <13:
        raise ValueError
    if not len(inp) == 2:
         raise Exception
    if not year in years:
        raise Exception
    print('У', mes,  'місяці', year, 'року', main(first(years), mes, year), 'день(ів)')    
except ValueError:
    print('Помилка! некоректне введення року або номера місяця ')
except Exception:
    print('Помилка! некоректне введення даних')
# Out:
# У 4 місяці 2019 року 30 день(ів)
